# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
# basic libraries

# %%
dataset = pd.read_csv('Desktop/training/Sales_Transactions_Dataset_Weekly.csv')
# read csv file

# %%
dataset
# show dataset
# Out:
#     Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8  ...  Normalized 42  \
# 0             P1  11  12  10   8  13  12  14  21   6  ...           0.06
# 1             P2   7   6   3   2   7   1   6   3   3  ...           0.20
# 2             P3   7  11   8   9  10   8   7  13  12  ...           0.27
# 3             P4  12   8  13   5   9   6   9  13  13  ...           0.41
# 4             P5   8   5  13  11   6   7   9  14   9  ...           0.27
# 5             P6   3   3   2   7   6   3   8   6   6  ...           0.36
# 6             P7   4   8   3   7   8   7   2   3  10  ...           0.20
# 7             P8   8   6  10   9   6   8   7   5  10  ...           0.58
# 8             P9  14   9  10   7  11  15  12   7  13  ...           0.53
# 9            P10  22  19  19  29  20  16  26  20  24  ...           0.21
# 10           P11  15   7  15  14  17   7  10  16  11  ...           0.38
# 11           P12   3   4   1   6   4   3   7   3   5  ...           0.44
# ...

# %%
# to check the columns in dataset
list(dataset)
# Out:
# ['Product_Code',
#  'W0',
#  'W1',
#  'W2',
#  'W3',
#  'W4',
#  'W5',
#  'W6',
#  'W7',
#  'W8',
#  'W9',
#  'W10',
#  'W11',
#  'W12',
#  'W13',
#  'W14',
#  'W15',
#  'W16',
#  'W17',
#  'W18',
#  'W19',
#  'W20',
#  'W21',
#  'W22',
#  'W23',
#  'W24',
#  'W25',
#  'W26',
#  'W27',
#  'W28',
#  'W29',
#  'W30',
#  'W31',
#  'W32',
#  'W33',
#  'W34',
#  'W35',
#  'W36',
#  'W37',
#  'W38',
#  'W39',
#  'W40',
#  'W41',
#  'W42',
#  'W43',
#  'W44',
#  'W45',
#  'W46',
#  'W47',
#  'W48',
#  'W49',
#  'W50',
#  'W51',
#  'MIN',
#  'MAX',
#  'Normalized 0',
#  'Normalized 1',
#  'Normalized 2',
#  'Normalized 3',
#  'Normalized 4',
#  'Normalized 5',
#  'Normalized 6',
#  'Normalized 7',
#  'Normalized 8',
#  'Normalized 9',
#  'Normalized 10',
#  'Normalized 11',
#  'Normalized 12',
#  'Normalized 13',
#  'Normalized 14',
#  'Normalized 15',
#  'Normalized 16',
#  'Normalized 17',
#  'Normalized 18',
#  'Normalized 19',
#  'Normalized 20',
#  'Normalized 21',
#  'Normalized 22',
# ...

# %%
# to get the info data
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811 entries, 0 to 810
# Columns: 107 entries, Product_Code to Normalized 51
# dtypes: float64(52), int64(54), object(1)
# memory usage: 678.0+ KB
# None

# %%
# unique values for certain column
dataset['Product_Code'].unique()
# Out:
# array(['P1', 'P2', 'P3', 'P4', 'P5', 'P6', 'P7', 'P8', 'P9', 'P10', 'P11',
#        'P12', 'P13', 'P14', 'P15', 'P16', 'P17', 'P18', 'P19', 'P20',
#        'P21', 'P22', 'P23', 'P24', 'P25', 'P26', 'P27', 'P28', 'P29',
#        'P30', 'P31', 'P32', 'P33', 'P34', 'P35', 'P36', 'P37', 'P38',
#        'P39', 'P40', 'P41', 'P42', 'P43', 'P44', 'P45', 'P46', 'P47',
#        'P48', 'P49', 'P50', 'P51', 'P52', 'P53', 'P54', 'P55', 'P56',
#        'P57', 'P58', 'P59', 'P60', 'P61', 'P62', 'P63', 'P64', 'P65',
#        'P66', 'P67', 'P68', 'P69', 'P70', 'P71', 'P72', 'P73', 'P74',
#        'P75', 'P76', 'P77', 'P78', 'P79', 'P80', 'P81', 'P82', 'P83',
#        'P84', 'P85', 'P86', 'P87', 'P88', 'P89', 'P90', 'P91', 'P92',
#        'P93', 'P94', 'P95', 'P96', 'P97', 'P98', 'P99', 'P100', 'P101',
#        'P102', 'P103', 'P104', 'P105', 'P106', 'P107', 'P108', 'P109',
#        'P110', 'P111', 'P112', 'P113', 'P114', 'P115', 'P116', 'P117',
# ...

# %%
# If we want the the unique values of the column in pandas data frame as a list, we can easily apply the function tolist() by chaining it to the previous command.
dataset['Product_Code'].unique().tolist()
# Out:
# ['P1',
#  'P2',
#  'P3',
#  'P4',
#  'P5',
#  'P6',
#  'P7',
#  'P8',
#  'P9',
#  'P10',
#  'P11',
#  'P12',
#  'P13',
#  'P14',
#  'P15',
#  'P16',
#  'P17',
#  'P18',
#  'P19',
#  'P20',
#  'P21',
#  'P22',
#  'P23',
#  'P24',
#  'P25',
#  'P26',
#  'P27',
#  'P28',
#  'P29',
#  'P30',
#  'P31',
#  'P32',
#  'P33',
#  'P34',
#  'P35',
#  'P36',
#  'P37',
#  'P38',
#  'P39',
#  'P40',
#  'P41',
#  'P42',
#  'P43',
#  'P44',
#  'P45',
#  'P46',
#  'P47',
#  'P48',
#  'P49',
#  'P50',
#  'P51',
#  'P52',
#  'P53',
#  'P54',
#  'P55',
#  'P56',
#  'P57',
#  'P58',
#  'P59',
#  'P60',
#  'P61',
#  'P62',
#  'P63',
#  'P64',
#  'P65',
#  'P66',
#  'P67',
#  'P68',
#  'P69',
#  'P70',
#  'P71',
#  'P72',
#  'P73',
#  'P74',
#  'P75',
#  'P76',
#  'P77',
#  'P78',
#  'P79',
#  'P80',
#  'P81',
#  'P82',
#  'P83',
#  'P84',
#  'P85',
#  'P86',
#  'P87',
#  'P88',
#  'P89',
#  'P90',
#  'P91',
#  'P92',
#  'P93',
#  'P94',
#  'P95',
#  'P96',
#  'P97',
#  'P98',
#  'P99',
#  'P100',
# ...

# %%
# we can simply count the number of unique values in the product_code column 
len(dataset['Product_Code'].unique().tolist())
# Out:
# 811

# %%
# function counts the number of values in each column.
dataset.count()
# Out:
# Product_Code     811
# W0               811
# W1               811
# W2               811
# W3               811
# W4               811
# W5               811
# W6               811
# W7               811
# W8               811
# W9               811
# W10              811
# W11              811
# W12              811
# W13              811
# W14              811
# W15              811
# W16              811
# W17              811
# W18              811
# W19              811
# W20              811
# W21              811
# W22              811
# W23              811
# W24              811
# W25              811
# W26              811
# W27              811
# W28              811
#                 ...
# Normalized 22    811
# Normalized 23    811
# Normalized 24    811
# Normalized 25    811
# Normalized 26    811
# Normalized 27    811
# Normalized 28    811
# Normalized 29    811
# Normalized 30    811
# Normalized 31    811
# Normalized 32    811
# Normalized 33    811
# ...

# %%
# If you want to make your output clearer, you can select the Product_Code column first 
dataset[['Product_Code']].count()
# dataset.Product_Code.count() another syntax that can be apply
# Out:
# Product_Code    811
# dtype: int64

# %%
X = dataset.iloc[:,:53]
# extract till columns 53 
# http://www.datasciencemadesimple.com/indexing-iloc-loc-ix-pandas-python/

# %%
X
# Out:
#     Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8  ...  W42  W43  W44  W45  \
# 0             P1  11  12  10   8  13  12  14  21   6  ...    4    7    8   10
# 1             P2   7   6   3   2   7   1   6   3   3  ...    2    4    5    1
# 2             P3   7  11   8   9  10   8   7  13  12  ...    6   14    5    5
# 3             P4  12   8  13   5   9   6   9  13  13  ...    9   10    3    4
# 4             P5   8   5  13  11   6   7   9  14   9  ...    7   11    7   12
# 5             P6   3   3   2   7   6   3   8   6   6  ...    4    2    4    3
# 6             P7   4   8   3   7   8   7   2   3  10  ...    2    3    3    6
# 7             P8   8   6  10   9   6   8   7   5  10  ...   10   14    4    8
# 8             P9  14   9  10   7  11  15  12   7  13  ...   11    5   13    3
# 9            P10  22  19  19  29  20  16  26  20  24  ...   14   17   11   24
# 10           P11  15   7  15  14  17   7  10  16  11  ...   11   16   12   11
# ...

# %%
X.mean(1)
# X.mean(axis=1)
# find mean for each row
# Out:
# 0       9.634615
# 1       3.980769
# 2       8.692308
# 3       8.269231
# 4       8.461538
# 5       4.230769
# 6       4.096154
# 7       8.653846
# 8      10.365385
# 9      19.423077
# 10     11.557692
# 11      3.903846
# 12      9.038462
# 13     11.826923
# 14     34.711538
# 15     36.057692
# 16     33.942308
# 17     32.346154
# 18     32.442308
# 19      8.942308
# 20      8.884615
# 21      9.365385
# 22      4.134615
# 23     36.096154
# 24     30.807692
# 25     10.288462
# 26     34.692308
# 27     32.615385
# 28     12.076923
# 29     32.500000
#          ...
# 781     2.423077
# 782     5.519231
# 783     1.423077
# 784     3.019231
# 785     0.653846
# 786     0.442308
# 787     3.326923
# 788     2.942308
# 789     2.288462
# 790     4.826923
# 791     1.461538
# 792     2.884615
# 793     0.730769
# 794     3.557692
# 795     2.923077
# 796     2.653846
# 797     5.173077
# 798     1.307692
# 799     3.115385
# 800     0.769231
# 801     0.384615
# ...

# %%
X.dtypes
# To check the dataype for each columns
# Out:
# Product_Code    object
# W0               int64
# W1               int64
# W2               int64
# W3               int64
# W4               int64
# W5               int64
# W6               int64
# W7               int64
# W8               int64
# W9               int64
# W10              int64
# W11              int64
# W12              int64
# W13              int64
# W14              int64
# W15              int64
# W16              int64
# W17              int64
# W18              int64
# W19              int64
# W20              int64
# W21              int64
# W22              int64
# W23              int64
# W24              int64
# W25              int64
# W26              int64
# W27              int64
# W28              int64
# W29              int64
# W30              int64
# W31              int64
# W32              int64
# W33              int64
# W34              int64
# W35              int64
# W36              int64
# W37              int64
# W38              int64
# ...

# %%
X.info()
# show more useful infos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811 entries, 0 to 810
# Data columns (total 53 columns):
# Product_Code    811 non-null object
# W0              811 non-null int64
# W1              811 non-null int64
# W2              811 non-null int64
# W3              811 non-null int64
# W4              811 non-null int64
# W5              811 non-null int64
# W6              811 non-null int64
# W7              811 non-null int64
# W8              811 non-null int64
# W9              811 non-null int64
# W10             811 non-null int64
# W11             811 non-null int64
# W12             811 non-null int64
# W13             811 non-null int64
# W14             811 non-null int64
# W15             811 non-null int64
# W16             811 non-null int64
# W17             811 non-null int64
# W18             811 non-null int64
# W19             811 non-null int64
# W20             811 non-null int64
# W21             811 non-null int64
# W22             811 non-null int64
# ...
